# %%
#import libraries
import pandas as pd
import re
import time
import os
from itertools import chain
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
pd.set_option("display.max_rows", None)
#check working path
os.getcwd()
# Out:
# '/Users/marysolomon/Desktop/KPOPThesis'

# %%
#Load and head artist data.
artist_df = pd.read_csv("artist_df.csv",index_col=0).tail(1)
artist_df.head(n = 5)
# Out:
#         Artist                                     ID  Type Gender  \
# 180  J.Y. Park  spotify:artist:1TTx0YcbKUtJIZY1HEnh9B  solo   male
#
#      Generation  DebutYear
# 180         1.0       1994

# %%
# Load and head songs meta data table
songs_df = pd.read_csv("songs_meta_table_unclean3.csv",index_col=0)
print('total rows in song meta data table: ', len(songs_df))
#only keep unique song uri ids.
print('total unique songs by uri table: ', len(pd.unique(songs_df['song_uri'])))
#songs_df = songs_df[songs_df['song_uri'].drop_duplicates()]
songs_df.head(n=5)
# Out:
# total rows in song meta data table:  6609
# total unique songs by uri table:  6609
#                     song_name                              song_uri  \
# 0  우리 함께라면 (From. "드라마 최강칠우")  spotify:track:0CTOSVnM9PpeB5FW28fdAK
# 1       오버 센스 - Remix version  spotify:track:3yBjWbZF6x7xud5yndy9VK
# 2                      Father  spotify:track:67GqQCeymrQlNkciuANkuV
# 3           Despacito - Remix  spotify:track:0Qs15CrEvM4rLabVSF9ECG
# 4             Sunshine - Edit  spotify:track:2Orv75XbBYxVjXQdsAq0KZ
#
#                       album                             album_uri  \
# 0                        인연  spotify:album:4tNYcoG7KmE4toxCvnHKQA
# 1  MILLENNIUM DANCE MEGAMIX  spotify:album:3jvN2pj94p2IJBQIoyDFF7
# 2                    No. 18  spotify:album:0y1oIfGo1T3NoHuC7lY8Rg
# 3           25 Ans Ultratop  spotify:album:033OTl57rnhrr0522v0UXe
# 4              Beach Party!  spotify:album:0yyLR7lTfeRc3lXAFTGzOt
#
#             artist                             artist_uri release_date  \
# 0  Various Artists  spotify:artist:0LyfQWJT6nXafLPZqxe9Of   2009-12-09
# 1            TURBO  spotify:artist:3aboSJaljyYlTRXt7pEH0G   1999-07-15
# 2              PSY  spotify:artist:2dd5mrQZvg6SmahdgVKDzh   2005-07-23
# 3  Various Artists  spotify:artist:0LyfQWJT6nXafLPZqxe9Of   2020-09-11
# 4  Various Artists  spotify:artist:0LyfQWJT6nXafLPZqxe9Of   2020-07-24
#
#    popularity  duration_ms
# 0           6       192473
# 1           0        97097
# 2          26       208546
# 3           5       230693
# 4           0       207421

# %%
# see if number of artists match
#detect artists to remove
uri1 = pd.unique(artist_df['ID'])
uri2 = pd.unique(songs_df['artist_uri'])
artists1 = artist_df['Artist']
artists2 = pd.unique(songs_df['artist'])

print(len(artists1))
print(len(uri1))
print(len(uri2))
print(len(artists2))
# Out:
# 26
# 26
# 143
# 143

# %%
#### identifying subset of the artist table
# artists1[154:]
# artist_df[154:]

# %%
#### Take a look at all the artists included in the unclean songs list.
artists_sorted = songs_df[['artist','artist_uri']].drop_duplicates().sort_values(by=['artist'], ascending=True)
artists_sorted
#### There are clearly alot that we do not want to include unless there was a collab with a kpop artist
# Out:
#                                          artist  \
# 401                                  #ENT Works
# 30                                     (G)I-DLE
# 718                                       2LSON
# 65                                         2NE1
# 127                                    88rising
# 118                             A June & J Beat
# 939                                          AJ
# 251                                        AKMU
# 641                                       AMBER
# 459                                     AOBeats
# 881                                        B1A4
# 3567                                   BAECHIGI
# 546                                    BAEKHYUN
# 11                                      BIGBANG
# 28                                    BLACKPINK
# 536                                        BOL4
# 826                                      Baauer
# 992                                     Babylon
# 284                                      Basick
# 265                             Black Eyed Peas
# 123                                     CHANGMO
# 210                                        CHEN
# 23                                     CHUNG HA
# 610                                          CL
# 448                                  CODE KUNST
# 2041                                       CUBE
# 1024                                 Chancellor
# 820                                       Crush
# 281                                        DEUX
# 972                                  DJ Negus I
# 4704                                    DPR IAN
# 427                                  Da Realest
# 1189                                       Dok2
# 665                                    Double K
# 236                                    Dua Lipa
# 180                                   Epik High
# 16                                     Eric Nam
# 14                                     Excision
# 13                                     G-DRAGON
# 84                                         G.NA
# 246                                      GD&TOP
# 93                                         Gain
# 1400                                    Gallant
# 5697                                       Gill
# 290                           Girls' Generation
# 4526                                    Grizzly
# 5507                                 GroovyRoom
# 358                                      H4rley
# 209                                       Henry
# 504                                      Hwa Sa
# 223                                       HyunA
# 904                                   J.Y. Park
# 635                                      JENNIE
# 37                                     JONGHYUN
# 604                                     Ja Mezz
# 568                                      K.Will
# 701                                         KAI
# 27                                  KANG DANIEL
# 156                                  KIM YON JA
# 5848                                      KOLAJ
# 2057                               KWON SOON IL
# 2678                            Kang Seung Yoon
# 2988                                 KillaGramz
# 592                               Kim Hyun Chul
# 5                                     Kim Ximya
# 287                                      Kondor
# 263                                         LC9
# 202                                   LOEN TREE
# 349                                   Lady Gaga
# 34                                    Lee Hyori
# 2722                             Lee Seung Chul
# 15                                        LeeHi
# 2588                                 Lil Stinny
# 356                                 Lim Jae Bum
# 200                                        Loco
# 394                                       Loote
# 1252                                    MAMAMOO
# 1396                               MAX CHANGMIN
# 122                                     MC MONG
# 193                                        MOBB
# 5044                                       Maui
# 1583                                 OH MY GIRL
# 232                                       ONEWE
# 725                                    PARK WON
# 98                                       PEEJAY
# 2592                                    PKCZ(R)
# 2                                           PSY
# 1661                           Paolo Di Lorenzo
# 314                                    Park Bom
# 443                                  Park Boram
# 328                            Patrik Jablonski
# 2035                                   Paul Kim
# 898                                     Primary
# 845                                        RAVI
# 850                                      Raiden
# 221                                    Realslow
# 776                                 Roh Ji Hoon
# 2626                            Romantic Garden
# 264                                        Ryno
# 1285                                         S4
# 12                                   SANTALKING
# 690                                     SEUNGRI
# 179                                      SHINee
# 2039                                       SOMI
# 3943                                      SOYOU
# 549                                       SUNMI
# 1782                                      SURAN
# 2225                                     Samuel
# 2580                                      San E
# 1367                                 Springhead
# 1705                                Steve James
# 1041                                       Suzy
# 38                                       TAEMIN
# 42                                      TAEYANG
# 1175  spotify:artist:0FRUZvZNPzM3YJMABJxf2K
# 467   spotify:artist:6pC3vnUgNVITdYMMXefi6D
# 277   spotify:artist:7dkc1552SeWHN7TXNZLgia
# 598   spotify:artist:6iLGJqxVgxxWsJe5bW4dxt
# 2407  spotify:artist:4hyF8Vtc73RYJr3RgTE2Zf
# 44    spotify:artist:0XHtRkNPlsL3sUB1w5mDmh
# 1647  spotify:artist:0BD74hBusWzcPz44wFskYb
# 3250  spotify:artist:4zmCovcjfUoYP3VilaMGxb
# 4333  spotify:artist:4oH4QZuZSXhKMkaG0pXZf0
# 105   spotify:artist:0hW1muryuCdZLfjoLrUhnw
# 3232  spotify:artist:4XpUIb8uuNlIWVKmgKZXC0
# 756   spotify:artist:5HenzRvMtSrgtvU16XAoby
# 993   spotify:artist:3wcF65sQNRI8K9KBZTK9xG
# 45    spotify:artist:4UhiMIdxKqQxmzdE9nYe6O
# 499   spotify:artist:2UEnhov0KDPYU2dmGUjfcn
# 2773  spotify:artist:2LyRQyxlpUeP9NtLUM1kTT
# 1310  spotify:artist:79nE7RNTvx3vN9S7f3YY9o
# 758   spotify:artist:79z5LdKM4EGjyRChrLGAcK
# 5133  spotify:artist:2t1ip1Z9g4U5PIrBrGoS31
# 1770  spotify:artist:0BeIulKOpcvsabwlt4u8qp

# %%
#detect artists to remove based on URI
uri_rm = set(uri2) - set(uri1)
len(uri_rm)
# Out:
# 117

# %%
#### look at list of artists to remove based on artist name
artist_rm = set(artists2) - set(artists1)
len(artist_rm)
#artist_rm
# Out:
# 119

# %%
### detect which artists from my list that are not detected in the songs collection....
artist_om = set(artists1) - set(artists2)
len(artist_om)
artist_om
# Out:
# 2
# {'CHUNGHA', 'Taeyeon'}

# %%
# prepping to clean the songs meta data file.
# removes songs if their artist uris are in the uris to remove (artists not in scope of research)
type(songs_df['artist_uri'].isin(uri_rm)) #pandas boolean
# tilde removes rows where this condition is true.
songs_clean = songs_df[~songs_df['artist_uri'].isin(uri_rm)]
len(songs_clean)
songs_clean['artist'].drop_duplicates().head(n=10)
# Out:
# pandas.core.series.Series
# 1793
# 1           TURBO
# 2             PSY
# 13       G-DRAGON
# 15          LeeHi
# 16       Eric Nam
# 23       CHUNG HA
# 27    KANG DANIEL
# 28      BLACKPINK
# 34      Lee Hyori
# 37       JONGHYUN
# Name: artist, dtype: object

# %%
#This code finds song titles that contain artist name.
# songs_df['song_name'].str.contains('|'.join(artists1)).head(n=5)
# type(songs_df['song_name'].str.contains('|'.join(artists1))) #pandas boolean
# songs_df[songs_df['song_name'].str.contains('|'.join(artists1))].head(n=10)
# #this code finds artist names that contain the artist name
# songs_df['artist'].str.contains('|'.join(artists1)).head(n=5)
# type(songs_df['artist'].str.contains('|'.join(artists1)))
# songs_df[songs_df['artist'].str.contains('|'.join(artists1))].head(n=10)

# %%
### Put all three together separated by and operators.
#these are exceptions ot uri not matching
# songs_keep = songs_df[(songs_df['artist_uri'].isin(uri_rm)) & 
#                       ((songs_df['song_name'].str.contains('|'.join(artists1))) |
#                       (songs_df['artist'].str.contains('|'.join(artists1))))]
# len(songs_keep)
# songs_keep

# %%
#### songs to remove
# songs_remove = songs_df[(songs_df['artist_uri'].isin(uri_rm)) & 
#                       ~((songs_df['song_name'].str.contains('|'.join(artists1))) |
#                       (songs_df['artist'].str.contains('|'.join(artists1))))]
# len(songs_remove)
# songs_remove.head(n=10)

# %%
#### STEP 1. DROP IRRELEVANT ARTISTS ####
### drop songs in song meta table if 
### 1. the artist uri from artist dataframe is not present AND
### (2. for artist name is not in the song titles OR
### 3. artist name from artist df is not present in the artist names from songs df.)
#'|'.join(artists1)
#### current logic isn't working? need to execute more successfully.
songs_clean = songs_df[~((songs_df['artist_uri'].isin(uri_rm)) & 
                      ~((songs_df['song_name'].str.contains('|'.join(artists1))) |
                      (songs_df['artist'].str.contains('|'.join(artists1)))))]
print('total songs with unwanted artists removed: ', len(songs_clean))
songs_clean.head(n=10)
# Out:
# total songs with unwanted artists removed:  1823
#                   song_name                              song_uri  \
# 1     오버 센스 - Remix version  spotify:track:3yBjWbZF6x7xud5yndy9VK
# 2                    Father  spotify:track:67GqQCeymrQlNkciuANkuV
# 13            YOU DO _OUTRO  spotify:track:7BB3vubFA93s3lOr6Pid61
# 15               1, 2, 3, 4  spotify:track:2SfUyVfBg3XIsRxZSP41f7
# 16        Before the Sunset  spotify:track:1EzfapL0krLyoIxezUU3A6
# 23                     PLAY  spotify:track:1SdLedoEjrMRu5AnvK2EYk
# 25          Ooh Ooh (Inst.)  spotify:track:0HrA48QdPLJmSvbEqOTWGY
# 27                Adulthood  spotify:track:4MvPLt96ErbrqINiCpOwJ6
# 28  WHISTLE - Acoustic Ver.  spotify:track:60Z8ni1FA5lNhGhhDsiiCL
# 34                 Only One  spotify:track:0Nq0RlwahjmpUBNzn8SBsc
#
#                                               album  \
# 1                          MILLENNIUM DANCE MEGAMIX
# 2                                            No. 18
# 13     COUP D'ETAT [+ ONE OF A KIND & HEARTBREAKER]
# 15                                          1.2.3.4
# 16  Mad Dog, Pt. 1 (Original Television Soundtrack)
# 23                                             PLAY
# 25                                          Ooh Ooh
# 27                                         TOUCHIN'
# 28                                    Re: BLACKPINK
# 34                                         Stylish…
#
#                                album_uri       artist  \
# 1   spotify:album:3jvN2pj94p2IJBQIoyDFF7        TURBO
# 2   spotify:album:0y1oIfGo1T3NoHuC7lY8Rg          PSY
# 13  spotify:album:1mVPbaMZGsPh5gzhvO6BBX     G-DRAGON
# 15  spotify:album:38q5fFOBE33FKoJUOZfC0Z        LeeHi
# 16  spotify:album:6Zw40UVaZ6CDtTFLqoIDEe     Eric Nam
# 23  spotify:album:7tzaUrzvzQGfqvzsYzSODr     CHUNG HA
# 25  spotify:album:4AFxO6gMtKC8O1ksxjFncV     Eric Nam
# 27  spotify:album:08FjoakLYgsyA4NzfVPWke  KANG DANIEL
# 28  spotify:album:2Gz6UbNiSL1caVQBpExJ5x    BLACKPINK
# 34  spotify:album:2uTwUONoLUhlpM6r324B2b    Lee Hyori
#
#                                artist_uri release_date  popularity  \
# 1   spotify:artist:3aboSJaljyYlTRXt7pEH0G   1999-07-15           0
# 2   spotify:artist:2dd5mrQZvg6SmahdgVKDzh   2005-07-23          26
# 13  spotify:artist:30b9WulBM8sFuBo17nNq9c   2013-11-27           9
# 15  spotify:artist:7cVZApDoQZpS447nHTsNqu   2018-06-27           9
# 16  spotify:artist:2FLqlgckDKdmpBrvLAT5BM   2017-10-12          43
# 23  spotify:artist:2PSJ6YriU7JsFucxACpU7Y   2020-07-06          69
# 25  spotify:artist:2FLqlgckDKdmpBrvLAT5BM   2014-04-08           7
# 27  spotify:artist:5vGoWnZO65NBgiZYBmi3iW   2019-11-25          35
# 28  spotify:artist:41MozSoPIsD1dJM0CLPjZF   2018-03-28          20
# 34  spotify:artist:4FjoOJAndC0s9ZJUo6VGc5   2003-08-13          11
#
#     duration_ms
# 1         97097
# 2        208546
# 13       160026
# 15       214273
# 16       189905
# 23       199524
# 25       195273
# 27       185386
# 28       213066
# 34       233209

# %%
#### STEP 2. REMOVE LIVE/TOUR OR COMPILATION ALBUMS ####

words_rm = ['\slive\s', ' tour ', ' concert ', 'special event', 'best of']

#### Cleaning out albums with the following words in them: 'live', 'tour', 'concert', 'special event', 'the best of'
album_names = songs_clean['album'].drop_duplicates()
print('total number of albums: ',len(album_names))
album_names.head(n=10)

### Filter for albums with the keywords to see if successful :) 
# album_rm = songs_df[songs_df['album'].str.lower().str.contains('|'.join(words_rm))]['album'].drop_duplicates()
# print('total number of albums to remove: ',len(album_rm))
# album_rm

### removing songs from these albums from the dataset
songs_clean = songs_clean[~songs_clean['album'].str.lower().str.contains('|'.join(words_rm))]
print('number of songs when live/tour albums are removed: ' , len(songs_clean))
songs_clean.head(n=25)
# Out:
# total number of albums:  323
# 1                            MILLENNIUM DANCE MEGAMIX
# 2                                              No. 18
# 13       COUP D'ETAT [+ ONE OF A KIND & HEARTBREAKER]
# 15                                            1.2.3.4
# 16    Mad Dog, Pt. 1 (Original Television Soundtrack)
# 23                                               PLAY
# 25                                            Ooh Ooh
# 27                                           TOUCHIN'
# 28                                      Re: BLACKPINK
# 34                                           Stylish…
# Name: album, dtype: object
# number of songs when live/tour albums are removed:  1651
#                                song_name  \
# 1                  오버 센스 - Remix version
# 2                                 Father
# 13                         YOU DO _OUTRO
# 15                            1, 2, 3, 4
# 16                     Before the Sunset
# 23                                  PLAY
# 25                       Ooh Ooh (Inst.)
# 27                             Adulthood
# 28               WHISTLE - Acoustic Ver.
# 34                              Only One
# 37                             I’m sorry
# 38                       Just Me And You
# 40   Waves (feat. Simon Dominic & Jamie)
# 42          Connection - English Version
# 68                         Love Yourself
# 75               This Is Not A Love Song
# 76                                   도시인
# 79                        Crazy Over You
# 80                                     X
# 82           Count Down & Happy New Year
# 88                               E.M.M.M
# 91                                    선택
# 93                 Apple (feat.Jay Park)
# 95                              Amor Mio
# 107                                 LOVE
#
#                                  song_uri  \
# 1    spotify:track:3yBjWbZF6x7xud5yndy9VK
# 2    spotify:track:67GqQCeymrQlNkciuANkuV
# 13   spotify:track:7BB3vubFA93s3lOr6Pid61
# 15   spotify:track:2SfUyVfBg3XIsRxZSP41f7
# 16   spotify:track:1EzfapL0krLyoIxezUU3A6
# 23   spotify:track:1SdLedoEjrMRu5AnvK2EYk
# 25   spotify:track:0HrA48QdPLJmSvbEqOTWGY
# 27   spotify:track:4MvPLt96ErbrqINiCpOwJ6
# 28   spotify:track:60Z8ni1FA5lNhGhhDsiiCL
# 34   spotify:track:0Nq0RlwahjmpUBNzn8SBsc
# 37   spotify:track:7foTlQj81Z7Ckz9o4tU9yF
# 38   spotify:track:1Dgepi6GzDjCvcnd2p1OAy
# 40   spotify:track:6fXesHsuCFf80vYzDP26J5
# 42   spotify:track:5Tqnb5WsXWCRAVcu0bC7QV
# 68   spotify:track:5EcmSX3iRyxM1yFzdwPmse
# 75   spotify:track:0Fkod9SKPSHKQM2UtSH02Y
# 76   spotify:track:7KejIluBaqE2am34YXowde
# 79   spotify:track:4yOqfpzmL4FvmXJTUgAMUP
# 80   spotify:track:3uCzfBFBNh6WTzUMCk2wwG
# 82   spotify:track:1Zw18bJKaclhNdfFkUHaR2
# 88   spotify:track:5PjTTxVJyBhXOHsp7wc3OE
# 91   spotify:track:4kadhaH1SLZ4VkK4wqNZDA
# 93   spotify:track:13o6TmqhYoAy9V0hnIEpgt
# 95   spotify:track:1a1A8jCSIool6iV5mq2LAs
# 107  spotify:track:5k0FSFPd15YKe7y9NMfq9U
#
#                                                album  \
# 1                           MILLENNIUM DANCE MEGAMIX
# 2                                             No. 18
# 13      COUP D'ETAT [+ ONE OF A KIND & HEARTBREAKER]
# 15                                           1.2.3.4
# 16   Mad Dog, Pt. 1 (Original Television Soundtrack)
# 23                                              PLAY
# 25                                           Ooh Ooh
# 27                                          TOUCHIN'
# 28                                     Re: BLACKPINK
# 34                                          Stylish…
# 37              JONGHYUN The Collection "Story Op.1"
# 38   Never Gonna Dance Again : Act 1 - The 3rd Album
# 40               Waves (feat. Simon Dominic & Jamie)
# 42                               Solar International
# 68            It’s okay to be sensitive 2 OST Part.1
# 75                                          Honestly
# 76                                            No. 18
# 79                                         THE ALBUM
# 80                         Turbo - Reboot : The Best
# 82                             Dance Pt.y With Turbo
# 88                                        Dark Angel
# 91                                       280KM SPEED
# 93                                            Hawwah
# 95                                        MONOCHROME
# 107                                    PSY 8th 4X2=8
#
#                                 album_uri       artist  \
# 1    spotify:album:3jvN2pj94p2IJBQIoyDFF7        TURBO
# 2    spotify:album:0y1oIfGo1T3NoHuC7lY8Rg          PSY
# 13   spotify:album:1mVPbaMZGsPh5gzhvO6BBX     G-DRAGON
# 15   spotify:album:38q5fFOBE33FKoJUOZfC0Z        LeeHi
# 76   spotify:artist:2dd5mrQZvg6SmahdgVKDzh   2005-07-23           6
# 79   spotify:artist:41MozSoPIsD1dJM0CLPjZF   2020-10-02          54
# 80   spotify:artist:3aboSJaljyYlTRXt7pEH0G   2015-11-24           7
# 82   spotify:artist:3aboSJaljyYlTRXt7pEH0G   1997-11-29           1
# 88   spotify:artist:4FjoOJAndC0s9ZJUo6VGc5   2006-02-09          12
# 91   spotify:artist:3aboSJaljyYlTRXt7pEH0G   1995-01-01          12
# 93   spotify:artist:4R60A85t9mTZzCqJlVswuo   2015-03-12          28
# 95   spotify:artist:4FjoOJAndC0s9ZJUo6VGc5   2013-05-21          20
# 107  spotify:artist:2dd5mrQZvg6SmahdgVKDzh   2017-05-10          34
#
#      duration_ms
# 1          97097
# 2         208546
# 13        160026
# 15        214273
# 16        189905
# 23        199524
# 25        195273
# 27        185386
# 28        213066
# 34        233209
# 37        251309
# 38        213720
# 40        164920
# 42        212053
# 68        175921
# 75        210116
# 76        276640
# 79        161945
# 80        266541
# 82        103601
# 88        218906
# 91        239922
# 93        183419
# 95        240120
# 107       219668

# %%
#### STEP 3. REMOVE LIVE/INSTRUMENTAL/ALTERNATIVE LANGUAGE VERSION OF SONGS ####
#### Logic: these are just repeats of the original version of the song. 

#### remove songs with the following words in the title: 
words_rm = [' \-live ', ' \-\slive ', '\(live\s',
            'instrumental', ' inst\. ', '\s inst \s ', '\(inst\)',
           'jp ver', 'japanese ver', 'eng ver', 'english ver',
            'korean ver', 'kr ver', 'karaoke']


### isolate song names
print('total song names: ', len(songs_clean['song_name']))
song_names = songs_clean['song_name'].drop_duplicates()
print('total number of unique song_names: ',len(song_names))
song_names.head(n=10)

### Filter for albums with the keywords
# songs_rm = songs_clean[songs_clean['song_name'].str.lower().str.contains('|'.join(words_rm))]['song_name'].drop_duplicates()
# print('total number of songs to remove: ',len(songs_rm))
# songs_rm

### removing songs with these keywords from the dataset
songs_clean = songs_clean[~songs_clean['song_name'].str.lower().str.contains('|'.join(words_rm))]
print('number of songs when instrumental versions are removed: ' , len(songs_clean))
songs_clean.head(n=25)
# Out:
# total song names:  1651
# total number of unique song_names:  1256
# 1       오버 센스 - Remix version
# 2                      Father
# 13              YOU DO _OUTRO
# 15                 1, 2, 3, 4
# 16          Before the Sunset
# 23                       PLAY
# 25            Ooh Ooh (Inst.)
# 27                  Adulthood
# 28    WHISTLE - Acoustic Ver.
# 34                   Only One
# Name: song_name, dtype: object
# number of songs when instrumental versions are removed:  1465
#                                song_name  \
# 1                  오버 센스 - Remix version
# 2                                 Father
# 13                         YOU DO _OUTRO
# 15                            1, 2, 3, 4
# 16                     Before the Sunset
# 23                                  PLAY
# 25                       Ooh Ooh (Inst.)
# 27                             Adulthood
# 28               WHISTLE - Acoustic Ver.
# 34                              Only One
# 37                             I’m sorry
# 38                       Just Me And You
# 40   Waves (feat. Simon Dominic & Jamie)
# 68                         Love Yourself
# 75               This Is Not A Love Song
# 76                                   도시인
# 79                        Crazy Over You
# 80                                     X
# 82           Count Down & Happy New Year
# 88                               E.M.M.M
# 91                                    선택
# 93                 Apple (feat.Jay Park)
# 95                              Amor Mio
# 107                                 LOVE
# 108                               Page 0
#
#                                  song_uri  \
# 1    spotify:track:3yBjWbZF6x7xud5yndy9VK
# 2    spotify:track:67GqQCeymrQlNkciuANkuV
# 13   spotify:track:7BB3vubFA93s3lOr6Pid61
# 15   spotify:track:2SfUyVfBg3XIsRxZSP41f7
# 16   spotify:track:1EzfapL0krLyoIxezUU3A6
# 23   spotify:track:1SdLedoEjrMRu5AnvK2EYk
# 25   spotify:track:0HrA48QdPLJmSvbEqOTWGY
# 27   spotify:track:4MvPLt96ErbrqINiCpOwJ6
# 28   spotify:track:60Z8ni1FA5lNhGhhDsiiCL
# 34   spotify:track:0Nq0RlwahjmpUBNzn8SBsc
# 37   spotify:track:7foTlQj81Z7Ckz9o4tU9yF
# 38   spotify:track:1Dgepi6GzDjCvcnd2p1OAy
# 40   spotify:track:6fXesHsuCFf80vYzDP26J5
# 68   spotify:track:5EcmSX3iRyxM1yFzdwPmse
# 75   spotify:track:0Fkod9SKPSHKQM2UtSH02Y
# 76   spotify:track:7KejIluBaqE2am34YXowde
# 79   spotify:track:4yOqfpzmL4FvmXJTUgAMUP
# 80   spotify:track:3uCzfBFBNh6WTzUMCk2wwG
# 82   spotify:track:1Zw18bJKaclhNdfFkUHaR2
# 88   spotify:track:5PjTTxVJyBhXOHsp7wc3OE
# 91   spotify:track:4kadhaH1SLZ4VkK4wqNZDA
# 93   spotify:track:13o6TmqhYoAy9V0hnIEpgt
# 95   spotify:track:1a1A8jCSIool6iV5mq2LAs
# 107  spotify:track:5k0FSFPd15YKe7y9NMfq9U
# 108  spotify:track:10X2ihhKwPyKzo89h4965O
#
#                                                album  \
# 1                           MILLENNIUM DANCE MEGAMIX
# 2                                             No. 18
# 13      COUP D'ETAT [+ ONE OF A KIND & HEARTBREAKER]
# 15                                           1.2.3.4
# 16   Mad Dog, Pt. 1 (Original Television Soundtrack)
# 23                                              PLAY
# 25                                           Ooh Ooh
# 27                                          TOUCHIN'
# 28                                     Re: BLACKPINK
# 34                                          Stylish…
# 37              JONGHYUN The Collection "Story Op.1"
# 38   Never Gonna Dance Again : Act 1 - The 3rd Album
# 40               Waves (feat. Simon Dominic & Jamie)
# 68            It’s okay to be sensitive 2 OST Part.1
# 75                                          Honestly
# 76                                            No. 18
# 79                                         THE ALBUM
# 80                         Turbo - Reboot : The Best
# 82                             Dance Pt.y With Turbo
# 88                                        Dark Angel
# 91                                       280KM SPEED
# 93                                            Hawwah
# 95                                        MONOCHROME
# 107                                    PSY 8th 4X2=8
# 108                                           Page 0
#
#                                 album_uri       artist  \
# 1    spotify:album:3jvN2pj94p2IJBQIoyDFF7        TURBO
# 2    spotify:album:0y1oIfGo1T3NoHuC7lY8Rg          PSY
# 75   spotify:artist:2FLqlgckDKdmpBrvLAT5BM   2018-04-11          47
# 76   spotify:artist:2dd5mrQZvg6SmahdgVKDzh   2005-07-23           6
# 79   spotify:artist:41MozSoPIsD1dJM0CLPjZF   2020-10-02          54
# 80   spotify:artist:3aboSJaljyYlTRXt7pEH0G   2015-11-24           7
# 82   spotify:artist:3aboSJaljyYlTRXt7pEH0G   1997-11-29           1
# 88   spotify:artist:4FjoOJAndC0s9ZJUo6VGc5   2006-02-09          12
# 91   spotify:artist:3aboSJaljyYlTRXt7pEH0G   1995-01-01          12
# 93   spotify:artist:4R60A85t9mTZzCqJlVswuo   2015-03-12          28
# 95   spotify:artist:4FjoOJAndC0s9ZJUo6VGc5   2013-05-21          20
# 107  spotify:artist:2dd5mrQZvg6SmahdgVKDzh   2017-05-10          34
# 108  spotify:artist:3qNVuliS40BLgXGxhdBdqu   2018-08-10          43
#
#      duration_ms
# 1          97097
# 2         208546
# 13        160026
# 15        214273
# 16        189905
# 23        199524
# 25        195273
# 27        185386
# 28        213066
# 34        233209
# 37        251309
# 38        213720
# 40        164920
# 68        175921
# 75        210116
# 76        276640
# 79        161945
# 80        266541
# 82        103601
# 88        218906
# 91        239922
# 93        183419
# 95        240120
# 107       219668
# 108       187360

# %%
#### STEP 4: REMOVE DUPLICATE SONGS THAT HAVE DIFFERENT URIS #### 
#### songs are considered duplicates if the song name, artist name and album name match simultaneously.
#### songs of the same name and artist released on a different album may have been re-arranged, remixed etc.
#### These have been checked and do return the same audio features despite different song uris.
songs_clean = songs_clean.sort_values('popularity', ascending = False).drop_duplicates(subset = ['song_name', 'artist', 'album'], keep='first')
print('total songs: ', len(songs_clean))
# Out:
# total songs:  1327

# %%
#### STEP 5: EXPORT ####
### Export clean song metadata which has undergone the following filterings:
#### 1. remove songs by artists who's URIs are not from the artist dataframe with the exception of songs
####    who had a relevant artist's name in the song or artist (some list multiple)
#### 2. remove live/tour/compilation albums
#### 3. remove live/instrumental/karaoke songs
#### 4. remove duplicates
songs_clean.to_csv('songs_meta_table_clean3.csv')

# %%
twinsongs = songs_clean[songs_clean.duplicated(subset = ['song_name', 'artist', 'album'], keep = False)].sort_values(by=['song_name'], ascending=True)
len(twinsongs)
twinsongs.head(n=10)
# Out:
# 0
# Empty DataFrame
# Columns: [song_name, song_uri, album, album_uri, artist, artist_uri, release_date, popularity, duration_ms]
# Index: []

# %%
#### dropping duplicates
print('total unique songs: ', len(twinsongs.drop_duplicates(subset = ['song_name', 'artist', 'album'])))
dup_rm = twinsongs.sort_values('popularity', ascending = False).drop_duplicates(subset = ['song_name', 'artist', 'album'], keep='first')
dup_rm.sort_values(by=['song_name'], ascending=True).head(n=10)
print('duplicates removed keeping most popular', len(dup_rm))
# Out:
# total unique songs:  0
# Empty DataFrame
# Columns: [song_name, song_uri, album, album_uri, artist, artist_uri, release_date, popularity, duration_ms]
# Index: []
# duplicates removed keeping most popular 0
